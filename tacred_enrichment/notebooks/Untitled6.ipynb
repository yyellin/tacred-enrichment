# %%
import spacy
from spacy import displacy
from stanfordnlp.server import CoreNLPClient

# %%
from corenlp_dtree_visualizer.converters import _corenlp_dep_tree_to_spacy_dep_tree

# %%
nlp = spacy.load("en_core_web_md")

# %%
# Input text
text = 'The Jerusalem Foundation, a charity founded by Kollek 40 years ago, said he died of natural causes.'

# %%
# Get a dependency tree from a Stanford CoreNLP pipeline
with CoreNLPClient(annotators=['tokenize','ssplit','pos','lemma','ner','parse','depparse'],
        timeout=60000, memory='8G', output_format='json') as client:
    # submit the request to the server
    ann = client.annotate(text)
# Out:
# Starting server with command: java -Xmx8G -cp c:\Users\JYellin\re_1\stanford-corenlp-full-2018-10-05/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-c183f21ebfc24f07.props -preload tokenize,ssplit,pos,lemma,ner,parse,depparse

# %%
# Convert dependency tree formats
sent = ann['sentences'][0]
tree = _corenlp_dep_tree_to_spacy_dep_tree(sent['tokens'], sent['enhancedPlusPlusDependencies'])
tree["settings"] = {}
displacy.render(tree, style="dep", manual=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="26f31472d1fb464fa5783f15005d58c8-0" class="displacy" width="3725" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[ROOT]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ROOT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Jerusalem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Foundation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">charity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">founded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VBN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Kollek</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">40</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NNS</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ago</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">RB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VBD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PRP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">died</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VBD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">JJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">causes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NNS</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">.</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26f31472d1fb464fa5783f15005d58c8-0-0" stroke-width="2px" d="M70,877.0 C70,2.0 2500.0,2.0 2500.0,877.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26f31472d1fb464fa5783f15005d58c8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ROOT</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M2500.0,879.0 L2508.0,867.0 2492.0,867.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26f31472d1fb464fa5783f15005d58c8-0-1" stroke-width="2px" d="M595,877.0 C595,702.0 185.0,702.0 185.0,877.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26f31472d1fb464fa5783f15005d58c8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,879.0 L587,867.0 603,867.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26f31472d1fb464fa5783f15005d58c8-0-2" stroke-width="2px" d="M595,877.0 C595,614.5 365.0,614.5 365.0,877.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26f31472d1fb464fa5783f15005d58c8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,879.0 L587,867.0 603,867.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26f31472d1fb464fa5783f15005d58c8-0-3" stroke-width="2px" d="M2520,877.0 C2520,789.5 530.0,789.5 530.0,877.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26f31472d1fb464fa5783f15005d58c8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M2520,879.0 L2512,867.0 2528,867.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26f31472d1fb464fa5783f15005d58c8-0-4" stroke-width="2px" d="M595,877.0 C595,527.0 720.0,527.0 720.0,877.0" fill="none" stroke=
