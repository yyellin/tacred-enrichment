# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas

train = pandas.read_csv(r'C:\Users\jyellin\re_1\Code\path_to_re\train-ucca_paths_per_relation.csv')
test = pandas.read_csv(r'C:\Users\jyellin\re_1\Code\path_to_re\test-ucca_paths_per_relation.csv')

# %%
test_total_by_r_and_p = test.groupby(['relation','path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation','total'], ascending=[False,False]).reset_index(drop=True)
train_total_by_r_and_p = train.groupby(['relation','path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation','total'], ascending=[True,False]).reset_index(drop=True)
train_total_by_p = train.groupby(['path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['total'], ascending=[False]).reset_index(drop=True)

# %%
def label_count_in_train_across_relations(test_row):
    path = test_row['path']

    train_row = train_total_by_p.loc[train_total_by_p['path'] == path]
    if train_row.empty:
        return 0
    else:
        compare  = train_row.values[0][1]
        return compare

def label_count_in_train_by_relation(test_row):
    relation = test_row['relation']
    path = test_row['path']

    train_row = train_total_by_r_and_p.loc[
        (train_total_by_r_and_p['relation'] == relation) & 
        (train_total_by_r_and_p['path'] == path)]
    if train_row.empty:
        return 0
    else:
        compare  = train_row.values[0][2]
        return compare

test_total_by_r_and_p['total-for-relation'] = test_total_by_r_and_p.apply(lambda row : label_count_in_train_by_relation(row), axis=1)
test_total_by_r_and_p['total-across-relations'] = test_total_by_r_and_p.apply(lambda row : label_count_in_train_across_relations(row), axis=1)

# %%
stats = []
relations = train_total_by_r_and_p['relation'].unique().tolist()
for relation in relations:
    
    df = test_total_by_r_and_p[test_total_by_r_and_p['relation']==relation]
    
    matched = sum(df[df['total-for-relation']>0]['total'].to_list())
    matched_lax = sum(df[df['total-across-relations']>0]['total'].to_list())
    total = sum(df['total'].to_list())
    
    stats.append( (relation, round(matched/total,4), round(matched_lax/total,4) ) )

    
matched = sum(test_total_by_r_and_p[test_total_by_r_and_p['total-for-relation']>0]['total'].to_list())
matched_lax = sum(test_total_by_r_and_p[test_total_by_r_and_p['total-across-relations']>0]['total'].to_list())
total = sum(test_total_by_r_and_p['total'].to_list())

stats.insert(0, ('overall', round(matched/total,4) , round(matched_lax/total),2) )
stats = sorted(stats, key=lambda x: x[1], reverse=True)

# %%
import plotly.graph_objs as go

trace1 = go.Bar(
    x=[stat[0] for stat in stats],
    y=[stat[2] for stat in stats],
    name='Pseudo Recall',
    width=0.5,
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=0.5),
        ),
    opacity=0.6
)

overall_index = next(i for (i, stat) in enumerate(stats) if stat[0] == 'overall')

colors = ['rgb(58,200,225)'] * len(stats)
colors[overall_index] = 'rgb(181,59,89)'


trace2 = go.Bar(
    x=[stat[0] for stat in stats],
    y=[stat[1] for stat in stats],
    name='Recall',
    width=0.5,
    marker=dict(
        color=colors,
        line=dict(
            color='rgb(8,48,107)',
            width=0.5),
        ),
    opacity=0.6
)

data = [trace2]
layout = go.Layout(
    title='UCCA Path - Recall',
    xaxis_title="Relation",
    yaxis_title="Recall",        
    barmode='overlay',
    width=1200,
    xaxis = go.layout.XAxis(
        tickangle = 45,
        automargin = True
        
    )
    
        
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="f074e5c3-7634-4b22-9f91-3fcd1e1f8113" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f074e5c3-7634-4b22-9f91-3fcd1e1f8113")) {
#                     Plotly.newPlot(
#                         'f074e5c3-7634-4b22-9f91-3fcd1e1f8113',
#                         [{"marker": {"color": ["rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(181,59,89)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)", "rgb(58,200,225)"], "line": {"color": "rgb(8,48,107)", "width": 0.5}}, "name": "Recall", "opacity": 0.6, "type": "bar", "uid": "9443567b-6147-418b-a20b-b731087f834a", "width": 0.5, "x": ["org:top_members/employees", "per:title", "org:alternate_names", "per:age", "org:founded", "per:date_of_birth", "per:origin", "per:employee_of", "org:city_of_headquarters", "per:stateorprovinces_of_residence", "overall", "per:cities_of_residence", "org:number_of_employees/members", "org:parents", "org:founded_by", "org:subsidiaries", "per:countries_of_residence", "per:city_of_birth", "per:spouse", "org:political/religious_affiliation", "org:stateorprovince_of_headquarters", "org:country_of_headquarters", "per:schools_attended", "per:date_of_death", "per:alternate_names", "per:other_family", "per:stateorprovince_of_birth", "per:siblings", "per:religion", "org:website", "per:parents", "per:country_of_birth", "org:member_of", "per:children", "per:charges", "per:city_of_death", "per:cause_of_death", "org:shareholders", "per:stateorprovince_of_death", "org:members", "org:dissolved", "per:country_of_death"], "y": [0.8772, 0.8548, 0.8473, 0.8368, 0.8286, 0.7778, 0.7717, 0.7638, 0.7532, 0.6835, 0.6812, 0.6576, 0.6316, 0.6271, 0.6212, 0.6136, 0.6069, 0.6, 0.5692, 0.5556, 0.5208, 0.5189, 0.5172, 0.5094, 0.5, 0.5, 0.5, 0.4808, 0.4783, 0.4545, 0.407, 0.4, 0.3529, 0.3143, 0.3011, 0.2963, 0.2766, 0.1667, 0.1429, 0.1333, 0.0, 0.0]}],
#                         {"barmode": "overlay", "title": {"text": "UCCA Path - Recall"}, "width": 1200, "xaxis": {"automargin": true, "tickangle": 45, "title": {"text": "Relation"}}, "yaxis": {"title": {"text": "Recall"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f074e5c3-7634-4b22-9f91-3fcd1e1f8113');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
