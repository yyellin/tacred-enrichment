# %%
from grakel import GraphKernel, datasets
# Out:
# C:\Users\jyellin\AppData\Local\Continuum\anaconda3\envs\msc_grakel\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\jyellin\AppData\Local\Continuum\anaconda3\envs\msc_grakel\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.lfw module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#wl_kernel = GraphKernel(kernel = [{"name": "weisfeiler_lehman", "n_iter": 5}, "subtree_wl"], normalize=True)

# %%
import pandas
ud_train = pandas.read_csv(r'C:\Users\jyellin\re_1\Code\path_to_re\train-ud_paths_per_relation.csv')
ud_train = ud_train[ud_train['relation'] == 'per:age']

# %%
path_to_count = ud_train.groupby(['path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['total'], ascending=[False]).reset_index(drop=True)

# %%
path_to_count
# Out:
#                                             path  total
# 0                                          >amod    160
# 1                                         <nsubj     30
# 2                                         >appos     15
# 3                                <nsubj >nmod:at     14
# 4                        <nsubj >nmod:at >nummod     10
# ..                                           ...    ...
# 126         <nmod:poss <nmod:at >nsubjpass >amod      1
# 127             <nmod:poss <nmod:at >nsubj >amod      1
# 128        <nmod:poss <nmod:at >nsubj >acl:relcl      1
# 129  <nmod:poss <dobj <xcomp <advcl >nsubj >amod      1
# 130                 >parataxis >dep >nsubj >amod      1
#
# [131 rows x 2 columns]

# %%
#df.loc[df['Language'].apply(lambda x: x in ['C', 'C++'] )])
high_counts = path_to_count.loc[ path_to_count['path'].apply(lambda x: len(x.split())<4) ]
high_counts
# Out:
#                                   path  total
# 0                                >amod    160
# 1                               <nsubj     30
# 2                               >appos     15
# 3                      <nsubj >nmod:at     14
# 4              <nsubj >nmod:at >nummod     10
# 5                              >nummod      6
# 6                         >appos >amod      5
# 7                           >acl:relcl      5
# 8             <nsubj >nmod:at >nmod:of      5
# 9                         <appos >amod      4
# 12                 >acl:relcl >nmod:at      2
# 14      <nmod:poss <nmod:with >nmod:at      2
# 18              <nsubj >ccomp >nmod:at      2
# 19                  <acl:relcl >nummod      2
# 21                            >nmod:at      2
# 22                       <appos >appos      2
# 23          <nsubj >ccomp >advcl:until      1
# 24                       <nsubj >ccomp      1
# 25                        <nsubj >amod      1
# 26              <nsubj >advcl >nmod:of      1
# 28                 <nsubj >advcl >dobj      1
# 32                       <nsubj >advcl      1
# 33           <nsubj <parataxis >nummod      1
# 41        <nsubj <advcl:like <conj:and      1
# 42                    <acl:relcl >amod      1
# 44                  <xcomp <acl >appos      1
# 45                     >nmod:as >appos      1
# 47                          >dep >amod      1
# 48                     >conj:and >amod      1
# 49                      >appos >nummod      1
# 50                 >appos >acl:in >dep      1
# 51                   >acl:relcl >nsubj      1
# 52               >acl:relcl >nmod:tmod      1
# 53      >acl:relcl >nmod:npmod >nummod      1
# 54         >acl:relcl >nmod:at >nummod      1
# 55                    >acl:relcl >dobj      1
# 56                 <nsubjpass >nmod:on      1
# 57                <nsubj >ccomp >nsubj      1
# 59                          <nsubjpass      1
# 62          <nsubj >nmod:npmod >nummod      1
# 63                     <nsubj >nmod:in      1
# 64          <nsubj >nmod:from >nmod:of      1
# 65               <nsubj >nmod:at >amod      1
# 66          <nsubj <advcl:after >nsubj      1
# 67               <nsubj >dobj >nmod:of      1
# 69            <nsubj >nmod:after >amod      1
# 70             <nmod:with >nsubj >amod      1
# 76                     <nmod:as >nsubj      1
# 78                  <dobj >nsubj >amod      1
# 83                          <det >amod      1
# 84                     <conj:and >amod      1
# 86                        <conj >appos      1
# 87                         <conj >amod      1
# 88               <conj <nsubj >nmod:at      1
# 89                   <compound >nummod      1
# 90                  <compound >nmod:at      1
# 92               <compound >dep >appos      1
# 94                     <compound >amod      1
# 96                      <appos >nummod      1
# 97                     <appos >nmod:of      1
# 98             <appos >acl:relcl >dobj      1
# 99                              <appos      1
# 105              <nmod:with >nmod:with      1
# 106  <nmod:throughout >nmod:throughout      1
# 109       <nmod:poss <nsubjpass <advcl      1
# 111            <nmod:poss <nsubj >amod      1

# %%
def path_to_grakel_graph(path):
    steps = path.split(' ')

    edges = []
    node_names = {}
    edge_names = {}
    
    node_id = 0
    node_names[node_id] = 'F'
    
    for step_i, step in enumerate(steps): # steps[:-1]
        
        node_name = 'E' if step_i < len(steps)-1 else 'L'
        node_id += 1
        
        node_names[node_id] = node_name
        
        direction = step[0]
        if direction == '>':
            edges.append( (node_id-1, node_id) )
            edge_names[(node_id-1, node_id)] = step[1:]
        else:
            edges.append( (node_id, node_id-1) )
            edge_names[(node_id, node_id-1)] = step[1:]
        
    
    return (edges, node_names, edge_names)

# %%
unique_paths = high_counts['path'].to_list()

# %%
X = []
for path in unique_paths:
    X.append(path_to_grakel_graph(path))
# Out:
# >
# <
# >
# <
# >
# <
# >
# >
# >
# >
# >
# >
# <
# >
# >
# <
# >
# >
# >
# <
# <
# >
# <
# >
# >
# <
# >
# >
# <
# >
# <
# >
# >
# <
# >
# <
# >
# <
# >
# >
# <
# >
# >
# <
# >
# <
# <
# >
# <
# <
# <
# <
# >
# <
# <
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# >
# <
# >
# <
# >
# >
# <
# <
# >
# >
# <
# >
# <
# >
# >
# <
# >
# >
# <
# <
# >
# <
# >
# >
# <
# >
# >
# <
# >
# >
# <
# >
# <
# >
# >
# <
# >
# <
# >
# <
# >
# <
# >
# <
# <
# >
# <
# >
# <
# >
# <
# >
# >
# <
# >
# <
# >
# <
# >
# <
# >
# >
# <
# <
# >
# <
# >
# <
# <
# <
# <
# <
# >

# %%
#wl_subtree = GraphKernel(kernel=['WL', 'ST-WL'], normalize=False)
wl_subtree = GraphKernel(kernel=['weisfeiler_lehman', 'edge_histogram'], normalize=False)

K = wl_subtree.fit_transform(X)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=30, verbose=0)
kmeans.fit(K)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=30, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
import pandas

cluster_mapping = pandas.DataFrame()

# %%
pandas.set_option('display.max_rows', 100)
cluster_mapping['path'] = unique_paths
cluster_mapping['cluster'] = kmeans.labels_
cluster_mapping.sort_values(['cluster'], ascending=[True])
# Out:
#                                  path  cluster
# 25                 <xcomp <acl >appos        0
# 61                             <appos        0
# 2                              >appos        0
# 59                    <appos >nmod:of        0
# 26                    >nmod:as >appos        0
# 51                       <conj >appos        0
# 17                      <nsubj >ccomp        1
# 16         <nsubj >ccomp >advcl:until        1
# 5                             >nummod        2
# 54                  <compound >nummod        2
# 27                         >dep >amod        3
# 49                         <det >amod        3
# 0                               >amod        3
# 57                    <compound >amod        3
# 52                        <conj >amod        3
# 53              <conj <nsubj >nmod:at        4
# 8            <nsubj >nmod:at >nmod:of        4
# 3                     <nsubj >nmod:at        4
# 12             <nsubj >ccomp >nmod:at        4
# 48                 <dobj >nsubj >amod        5
# 46            <nmod:with >nsubj >amod        5
# 45           <nsubj >nmod:after >amod        5
# 65            <nmod:poss <nsubj >amod        5
# 18                       <nsubj >amod        5
# 10                >acl:relcl >nmod:at        6
# 34        >acl:relcl >nmod:at >nummod        6
# 64       <nmod:poss <nsubjpass <advcl        7
# 43         <nsubj <advcl:after >nsubj        8
# 37               <nsubj >ccomp >nsubj        8
# 44              <nsubj >dobj >nmod:of        9
# 20                <nsubj >advcl >dobj        9
# 19             <nsubj >advcl >nmod:of        9
# 41         <nsubj >nmod:from >nmod:of        9
# 1                              <nsubj       10
# 47                    <nmod:as >nsubj       10
# 40                    <nsubj >nmod:in       10
# 23       <nsubj <advcl:like <conj:and       10
# 21                      <nsubj >advcl       10
# 38                         <nsubjpass       11
# 36                <nsubjpass >nmod:on       11
# 35                   >acl:relcl >dobj       12
# 39         <nsubj >nmod:npmod >nummod       13
# 22          <nsubj <parataxis >nummod       13
# 6                        >appos >amod       14
# 9                        <appos >amod       14
# 33     >acl:relcl >nmod:npmod >nummod       15
# 13                 <acl:relcl >nummod       15
# 62              <nmod:with >nmod:with       16
# 58                     <appos >nummod       17
# 29                     >appos >nummod       17
# 55                 <compound >nmod:at       18
# 14                           >nmod:at       18
# 63  <nmod:throughout >nmod:throughout       19
# 11     <nmod:poss <nmod:with >nmod:at       20
# 31                  >acl:relcl >nsubj       21
# 15                      <appos >appos       22
# 24                   <acl:relcl >amod       23
# 28                    >conj:and >amod       24
# 50                    <conj:and >amod       24
# 56              <compound >dep >appos       25
# 30                >appos >acl:in >dep       25
# 60            <appos >acl:relcl >dobj       26
# 42              <nsubj >nmod:at >amod       27
# 4             <nsubj >nmod:at >nummod       28
# 7                          >acl:relcl       29
# 32              >acl:relcl >nmod:tmod       29

# %%
import matplotlib.pyplot as plt
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black')

# %%
kmeans.cluster_centers_.shape
# Out:
# (5, 180)
