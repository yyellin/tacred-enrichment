# %%
import pandas

# %%
train = pandas.read_json(r'C:\Users\JYellin\re_1\tacred\data\json\train.json')

# %%
founded_by = train[train['relation']=='org:founded_by']

# %%
founded_by
# Out:
#                          id                             docid        relation  \
# 0      61b3a5c8c9a882dcfcd2  AFP_ENG_20070218.0019.LDC2009T13  org:founded_by
# 109    61b3a5c8c9129922723d  CNA_ENG_20071102.0005.LDC2009T13  org:founded_by
# 195    61b3a5c8c9b22380336d  APW_ENG_20080506.1399.LDC2009T13  org:founded_by
# 256    61b3a5c8c98cd06f7184  NYT_ENG_20070410.0207.LDC2009T13  org:founded_by
# 1631   61b3a5c8c9d78151c549  NYT_ENG_20070905.0002.LDC2009T13  org:founded_by
# ...                     ...                               ...             ...
# 66560  61b3a5c8c99a2bf11ee3  APW_ENG_20070703.1553.LDC2009T13  org:founded_by
# 66585  61b3a5c8c9d77f307d1f  NYT_ENG_20080404.0033.LDC2009T13  org:founded_by
# 66888  61b3a5c8c9ec325eea52  XIN_ENG_19960915.0156.LDC2007T07  org:founded_by
# 67322  61b3a5c8c93cc1cfb682  APW_ENG_20070102.0826.LDC2009T13  org:founded_by
# 68120  61b3a5c8c9208b8cbc50             NYT_ENG_20090919.0068  org:founded_by
#
# ...

# %%
#type(founded_by.apply(lambda row : len(row['token']), axis=1))
founded_by.loc[:,'len'] = founded_by.apply(lambda row : len(row['token']), axis=1)

# %%
founded_by = founded_by.sort_values(by=['len'], ascending=[True])

# %%
founded_by.head(20)
# Out:
#                          id                             docid        relation  \
# 36910  61b3a5c8c92325b9e966  AFP_ENG_20081208.0505.LDC2009T13  org:founded_by
# 66585  61b3a5c8c9d77f307d1f  NYT_ENG_20080404.0033.LDC2009T13  org:founded_by
# 37967  61b3a5c8c92bb7151c2b  APW_ENG_20080425.0502.LDC2009T13  org:founded_by
# 8330   61b3a5c8c9ef29835fa4  APW_ENG_20070419.1439.LDC2009T13  org:founded_by
# 11403  61b3a5c8c9b841ca301f  LTW_ENG_20070516.0003.LDC2009T13  org:founded_by
# 29363  61b3a5c8c901d9df74c6  APW_ENG_20071022.0218.LDC2009T13  org:founded_by
# 9299   61b3a5c8c9b7e21d7f6d          eng-NG-31-126841-9162020  org:founded_by
# 42772  61b3a5c8c9552e5b69a6  APW_ENG_20070124.1101.LDC2009T13  org:founded_by
# 35783  61b3a5c8c9e47d7cdfa2  APW_ENG_20070124.1101.LDC2009T13  org:founded_by
# 32586  61b3a5c8c9272ce895a6  APW_ENG_20070102.0370.LDC2009T13  org:founded_by
# 59578  61b3a5c8c9f95d60da9b          eng-NG-31-131701-9415297  org:founded_by
# ...
