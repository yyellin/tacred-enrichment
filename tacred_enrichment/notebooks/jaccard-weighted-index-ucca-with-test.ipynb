# %%
import numpy
import math
import pandas

# %%
ucca_train = pandas.read_csv(r'C:\Users\jyellin\re_1\Code\path_to_re\train-ucca_paths_per_relation.csv')
ucca_test = pandas.read_csv(r'C:\Users\jyellin\re_1\Code\path_to_re\test-ucca_paths_per_relation.csv')
jaccard_weighted_scores = []

# %%
ucca_train['source'] = 'train'

# %%
ucca_test['source'] = 'test'

# %%
ucca = pandas.concat([ucca_train, ucca_test])

# %%
ucca_stats_by_relation_and_path = ucca.groupby(['source','relation','path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation','source', 'total'], ascending=[True,True,False]).set_index(['relation','source'])
ucca_stats_by_relation = ucca.groupby(['source','relation'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation','source'], ascending=[True, True]).set_index(['relation','source'])

# %%
paths = ucca_stats_by_relation_and_path['path'].unique().tolist()
relations = ucca_stats_by_relation.index.get_level_values(0).unique().tolist()

path_to_index = {k: v for v, k in enumerate(paths)}
relation_to_index = {k: v for v, k in enumerate(relations)}

totals = ucca_stats_by_relation['total'].to_list()
mean_total = numpy.mean(totals)

# %%
relation_to_count_matrix_train = numpy.zeros((len(relations), len(paths)), dtype=numpy.intc)

for index, row in ucca_stats_by_relation_and_path.iterrows():
    
    if index[1] == 'test':
        continue
    
    relation = index[0]
    path = row['path']
    
    relation_index = relation_to_index[relation]
    path_index = path_to_index[path]
    
    total = row['total']
    if total == 1:
        total = 0
    relation_to_count_matrix_train[relation_index, path_index] = total

relation_to_count_df_train = pandas.DataFrame(relation_to_count_matrix_train, index=[relations,['train']*len(relations)], columns=paths)

# %%
relation_to_count_matrix_test = numpy.zeros((len(relations), len(paths)), dtype=numpy.intc)

for index, row in ucca_stats_by_relation_and_path.iterrows():
    
    if index[1] == 'train':
        continue
    
    relation = index[0]
    path = row['path']
    
    relation_index = relation_to_index[relation]
    path_index = path_to_index[path]
    
    total = row['total']
    if total == 1:
        total = 0
    relation_to_count_matrix_test[relation_index, path_index] = total

relation_to_count_df_test = pandas.DataFrame(relation_to_count_matrix_test, index=[relations,['test']*len(relations)], columns=paths)

# %%
relation_to_count_df = pandas.concat([relation_to_count_df_train, relation_to_count_df_test])

# %%
# create a single data frame from the total-relation counts and the relation-to-cound dataframe
temp = pandas.concat([ucca_stats_by_relation,relation_to_count_df], axis=1)

# filter out all relations for which there are less than 25% of the mean total sentences in the training set
temp = temp[temp['total'] >= mean_total/4]

# normalize counts 
temp = temp.apply( lambda x: x / x['total'] * mean_total, axis=1).drop(columns=['total'])

# round up to 
relation_to_count_normalized = temp.round(0).astype(int)

# %%
paths = ucca_stats_by_relation_and_path['path'].unique().tolist()
relations = ucca_stats_by_relation.index.get_level_values(0).unique().tolist()

for relation in relations:
    
    test_row = relation_to_count_normalized[
        (relation_to_count_normalized.index.get_level_values(0) == relation) &
        (relation_to_count_normalized.index.get_level_values(1) == 'test')]
    
    train_row = relation_to_count_normalized[
        (relation_to_count_normalized.index.get_level_values(0) == relation) &
        (relation_to_count_normalized.index.get_level_values(1) == 'train')]

    
    if (len(test_row) == 0 or len(train_row) == 0):
        continue
    
    numerator = 0
    denominator = 0
    
    for path in paths:
        test_row_count = 0
        if len(test_row[path].values) > 0:
            test_row_count = test_row[path].values[0]
            
        train_row_count = 0
        if len(train_row[path].values) > 0:
            train_row_count = train_row[path].values[0]
        
        numerator = numerator + min(test_row_count, train_row_count)
        denominator = denominator + max(test_row_count, train_row_count)
    
    if denominator > 0:
        jaccard_weighted_scores.append((relation, '{} (test)'.format(relation), numerator / denominator ))
        #scores[relation] = numerator / denominator

# %%
#score_df = pandas.DataFrame.from_dict(scores,  orient='index', columns=['score']).sort_values(['score'], ascending=[False] )
#score_df

# %%
ucca_train_stats_by_relation_and_path = ucca_train.groupby(['relation','path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation','total'], ascending=[True,False]).reset_index(drop=True)
ucca_train_stats_relation = ucca_train.groupby(['relation'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation'], ascending=[True]).set_index('relation')

# %%
paths = ucca_train_stats_by_relation_and_path['path'].unique().tolist()
relations = ucca_train_stats_by_relation_and_path['relation'].unique().tolist()

path_to_index = {k: v for v, k in enumerate(paths)}
relation_to_index = {k: v for v, k in enumerate(relations)}

totals = ucca_train_stats_relation['total'].to_list()
mean_total = numpy.mean(totals)

# %%
relation_to_count_matrix = numpy.zeros((len(relations), len(paths)), dtype=numpy.intc)

for index, row in ucca_train_stats_by_relation_and_path.iterrows():
    relation_index = relation_to_index[row['relation']]
    path_index = path_to_index[row['path']]
    
    total = row['total']
    if total <= 1:
        total = 0
    relation_to_count_matrix[relation_index, path_index] = total

relation_to_count_df = pandas.DataFrame(relation_to_count_matrix, index=relations, columns=paths)
#relation_to_count_matrix = numpy.concatenate((numpy.reshape(totals, (-1,1)),relation_to_count_matrix), axis=1)

# %%
# create a single data frame from the total-relation counts and the relation-to-cound dataframe
temp = pandas.concat([ucca_train_stats_relation,relation_to_count_df], axis=1)

# filter out all relations for which there are less than 25% of the mean total sentences in the training set
temp = temp[temp['total'] >= mean_total/4]

# normalize counts 
temp = temp.apply( lambda x: x / x['total'] * mean_total, axis=1).drop(columns=['total'])

# round up to 
relation_to_count_normalized = temp.round(0).astype(int)

# %%
relations = relation_to_count_normalized.index.to_list()
paths = relation_to_count_normalized.columns.to_list()
work = relation_to_count_normalized.to_numpy()

for i, i_relation in enumerate(relations):
    i_row = work[i]

    for j, j_relation in enumerate(relations[i+1:]):
        j_row = work[i+1+j]

        numerator = 0
        denominator = 0
        for k, k_path in enumerate(paths):
            numerator = numerator + min(i_row[k], j_row[k])
            denominator = denominator + max(i_row[k], j_row[k])
        
        jaccard_weighted_scores.append((i_relation, j_relation, numerator / denominator ))

# %%
from operator import itemgetter

jaccard_weighted_scores = sorted(jaccard_weighted_scores, key=itemgetter(2), reverse=True)
jaccard_weighted_scores_df = pandas.DataFrame.from_records(jaccard_weighted_scores, columns =['rel1', 'rel2', 'jaccard'])

# %%
pandas.set_option('display.max_rows', 100)
jaccard_weighted_scores_df.head(100)
# Out:
#                                    rel1  \
# 0                             per:title
# 1                   org:alternate_names
# 2             org:top_members/employees
# 3                       per:employee_of
# 4            per:countries_of_residence
# 5                               per:age
# 6                            per:origin
# 7            per:countries_of_residence
# 8               per:cities_of_residence
# 9            per:countries_of_residence
# 10                      per:employee_of
# 11             org:city_of_headquarters
# 12              per:cities_of_residence
# 13                      per:employee_of
# 14              per:cities_of_residence
# 15           per:countries_of_residence
# 16    per:stateorprovinces_of_residence
# 17             org:city_of_headquarters
# 18                     per:other_family
# 19              per:cities_of_residence
# 20                         per:siblings
# 21                           per:origin
# 22    per:stateorprovinces_of_residence
# 23                     per:other_family
# 24          org:country_of_headquarters
# 25                         per:children
# 26                   per:cause_of_death
# 27              per:cities_of_residence
# 28          org:country_of_headquarters
# 29             org:city_of_headquarters
# 30  org:political/religious_affiliation
# 31          org:country_of_headquarters
# 32           per:countries_of_residence
# 33              per:cities_of_residence
# 34                          org:parents
# 35                      per:employee_of
# 36          org:country_of_headquarters
# 37                          org:members
# 38                         per:children
# 39                          per:parents
# 40                   per:cause_of_death
# 41          org:country_of_headquarters
# 42                  org:alternate_names
# 43             org:city_of_headquarters
# 44                           per:origin
# 45                     org:subsidiaries
# 46              per:cities_of_residence
# 47                     per:other_family
# 48          org:country_of_headquarters
# 49                         per:children
# 50                  per:alternate_names
# 51                         per:children
# 52                           per:spouse
# 53                     org:subsidiaries
# 54                          org:parents
# 55                       org:founded_by
# 56              per:cities_of_residence
# 57                     org:subsidiaries
# 58  org:political/religious_affiliation
# 59          org:country_of_headquarters
# 60                       org:founded_by
# 61                       org:founded_by
# 62                          per:parents
# 63                    per:date_of_death
# 64                     org:subsidiaries
# 65                          per:charges
# 66          org:country_of_headquarters
# 67                  per:alternate_names
# 68                        org:member_of
# 69  org:stateorprovince_of_headquarters
# 70                     org:subsidiaries
# 71                          org:parents
# 72                     org:subsidiaries
# 73  org:political/religious_affiliation
# 74             org:city_of_headquarters
# 75                       org:founded_by
# 76            org:top_members/employees
# 77                          org:founded
# 78                        org:member_of
# 79                    per:city_of_death
# 80                          org:members
# 81             org:city_of_headquarters
# 82  org:stateorprovince_of_headquarters
# 83                         per:siblings
# 84                        org:member_of
# 85             org:city_of_headquarters
# 86                        org:member_of
# 87                       org:founded_by
# 88                  per:alternate_names
# 89  org:stateorprovince_of_headquarters
# 90              per:cities_of_residence
# 91                   per:cause_of_death
# 92                       org:founded_by
# 93                          org:parents
# 94                          org:parents
# 95             org:city_of_headquarters
# 96  org:political/religious_affiliation
# 97  org:stateorprovince_of_headquarters
# 98                          per:parents
# 99                           per:spouse
#
#                                           rel2   jaccard
# 0                             per:title (test)  0.612565
# 1                   org:alternate_names (test)  0.590244
# 2             org:top_members/employees (test)  0.539604
# 3                       per:employee_of (test)  0.507937
# 4                              per:employee_of  0.477352
# 5                               per:age (test)  0.446512
# 6                            per:origin (test)  0.438202
# 7            per:stateorprovinces_of_residence  0.432143
# 8               per:cities_of_residence (test)  0.429379
# 9            per:countries_of_residence (test)  0.420732
# 10           per:stateorprovinces_of_residence  0.419048
# 11         org:stateorprovince_of_headquarters  0.410596
# 12                  per:countries_of_residence  0.378378
# 13                                  per:origin  0.368098
# 14           per:stateorprovinces_of_residence  0.359621
# 15                                  per:origin  0.337793
# 16                                   per:title  0.337110
# 17                                 org:parents  0.325175
# 18                                per:siblings  0.320513
# 19                             per:employee_of  0.319767
# 20                                  per:spouse  0.318339
# 21           per:stateorprovinces_of_residence  0.317757
# 22    per:stateorprovinces_of_residence (test)  0.315217
# 23                                  per:spouse  0.295374
# 24           per:stateorprovinces_of_residence  0.295302
# 25                                  per:spouse  0.284768
# 26                           per:city_of_death  0.280702
# 27                        per:schools_attended  0.280488
# 28          org:country_of_headquarters (test)  0.279221
# 29             org:city_of_headquarters (test)  0.278351
# 30                                  per:origin  0.278351
# 31         org:stateorprovince_of_headquarters  0.273026
# 32                                   per:title  0.268362
# 33                           per:city_of_death  0.268293
# 34         org:stateorprovince_of_headquarters  0.267559
# 35                                   per:title  0.262755
# 36                                   per:title  0.257971
# 37                            org:subsidiaries  0.255474
# 38                                per:siblings  0.251880
# 39                                per:siblings  0.249110
# 40                        per:schools_attended  0.246622
# 41                                 org:parents  0.245421
# 42                                     per:age  0.244845
# 43                 org:country_of_headquarters  0.240385
# 44                                   per:title  0.239474
# 45                                  per:spouse  0.236422
# 46                                   per:title  0.234536
# 47                                 per:parents  0.232472
# 48                  per:countries_of_residence  0.226351
# 49                                 per:parents  0.226027
# 50                     per:cities_of_residence  0.224852
# 51                            per:other_family  0.224806
# 52                           per:spouse (test)  0.224490
# 53                            per:other_family  0.220930
# 54                          org:parents (test)  0.215190
# 55                                 org:parents  0.215017
# 56                                  per:origin  0.214689
# 57                                 per:parents  0.214286
# 58                             per:employee_of  0.211009
# 59                             per:employee_of  0.210059
# 60                                per:siblings  0.208904
# 61                            org:subsidiaries  0.208754
# 62                                  per:spouse  0.208333
# 63                    per:date_of_death (test)  0.207447
# 64                                per:siblings  0.207273
# 65                          per:charges (test)  0.207143
# 66                     per:cities_of_residence  0.205521
# 67                                  per:spouse  0.200581
# 68                     per:cities_of_residence  0.198606
# 69           per:stateorprovinces_of_residence  0.197183
# 70                                per:children  0.193662
# 71                                  per:spouse  0.192547
# 72                   org:top_members/employees  0.191892
# 73                  per:countries_of_residence  0.190476
# 74                              org:founded_by  0.188791
# 75                            per:other_family  0.187279
# 76                                  per:spouse  0.186441
# 77                           per:date_of_death  0.185629
# 78                  per:countries_of_residence  0.184906
# 79                  per:countries_of_residence  0.184049
# 80                   org:top_members/employees  0.182540
# 81                                   per:title  0.182500
# 82                  per:countries_of_residence  0.182353
# 83                         per:siblings (test)  0.178571
# 84           per:stateorprovinces_of_residence  0.178322
# 85                     per:cities_of_residence  0.177112
# 86                             per:employee_of  0.176471
# 87                                  per:spouse  0.175793
# 88                        per:schools_attended  0.175074
# 89  org:stateorprovince_of_headquarters (test)  0.175000
# 90                                  per:spouse  0.174731
# 91                     per:cities_of_residence  0.172727
# 92                   org:top_members/employees  0.172589
# 93                            org:subsidiaries  0.171329
# 94                                per:siblings  0.170819
# 95           per:stateorprovinces_of_residence  0.170799
# 96           per:stateorprovinces_of_residence  0.169279
# 97                     per:cities_of_residence  0.167568
# 98                          per:parents (test)  0.166667
# 99                                   per:title  0.165854
