# %%
import numpy
import math
import pandas
pandas.set_option('display.max_rows', 100)

# %%
ucca_train = pandas.read_csv(r'C:\Users\jyellin\re_1\Code\path_to_re\train-ucca_paths_per_relation.csv')

# %%
ucca_train_stats_by_relation_and_path = ucca_train.groupby(['relation','path'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation','total'], ascending=[True,False]).reset_index(drop=True)
ucca_train_stats_relation = ucca_train.groupby(['relation'])['id'].count().reset_index().rename(columns={'id': 'total'}).sort_values(['relation'], ascending=[True]).set_index('relation')

# %%
paths = ucca_train_stats_by_relation_and_path['path'].unique().tolist()
relations = ucca_train_stats_by_relation_and_path['relation'].unique().tolist()

path_to_index = {k: v for v, k in enumerate(paths)}
relation_to_index = {k: v for v, k in enumerate(relations)}

totals = ucca_train_stats_relation['total'].to_list()
mean_total = numpy.mean(totals)

# %%
relation_to_count_matrix = numpy.zeros((len(relations), len(paths)), dtype=numpy.intc)

for index, row in ucca_train_stats_by_relation_and_path.iterrows():
    relation_index = relation_to_index[row['relation']]
    path_index = path_to_index[row['path']]
    
    total = row['total']
    if total <= 1:
        total = 0
    relation_to_count_matrix[relation_index, path_index] = total

relation_to_count_df = pandas.DataFrame(relation_to_count_matrix, index=relations, columns=paths)
#relation_to_count_matrix = numpy.concatenate((numpy.reshape(totals, (-1,1)),relation_to_count_matrix), axis=1)

# %%
# create a single data frame from the total-relation counts and the relation-to-cound dataframe
temp = pandas.concat([ucca_train_stats_relation,relation_to_count_df], axis=1)

# filter out all relations for which there are less than 25% of the mean total sentences in the training set
temp = temp[temp['total'] >= mean_total/4]

# normalize counts 
temp = temp.apply( lambda x: x / x['total'] * mean_total, axis=1).drop(columns=['total'])

# round up to 
relation_to_count_normalized = temp.round(0).astype(int)

# %%
from operator import itemgetter

relations = relation_to_count_normalized.index.to_list()
paths = relation_to_count_normalized.columns.to_list()
work = relation_to_count_normalized.to_numpy()
jaccard_weighted_scores = []

for i, i_relation in enumerate(relations):
    i_row = work[i]

    for j, j_relation in enumerate(relations[i+1:]):
        j_row = work[i+1+j]

        numerator = 0
        denominator = 0
        for k, k_path in enumerate(paths):
            numerator = numerator + min(i_row[k], j_row[k])
            denominator = denominator + max(i_row[k], j_row[k])
        
        jaccard_weighted_scores.append((i_relation, j_relation, numerator / denominator ))
        

jaccard_weighted_scores = sorted(jaccard_weighted_scores, key=itemgetter(2), reverse=True)
jaccard_weighted_scores_df = pandas.DataFrame.from_records(jaccard_weighted_scores, columns =['rel1', 'rel2', 'jaccard'])

# %%
jaccard_weighted_scores_df.head(100)
# Out:
#                                    rel1                                 rel2  \
# 0            per:countries_of_residence                      per:employee_of
# 1            per:countries_of_residence    per:stateorprovinces_of_residence
# 2                       per:employee_of    per:stateorprovinces_of_residence
# 3              org:city_of_headquarters  org:stateorprovince_of_headquarters
# 4                    per:cause_of_death                    per:city_of_death
# 5     per:stateorprovinces_of_residence                            per:title
# 6               per:cities_of_residence           per:countries_of_residence
# 7                            per:origin    per:stateorprovinces_of_residence
# 8              org:city_of_headquarters                          org:parents
# 9                       per:employee_of                           per:origin
# 10  org:political/religious_affiliation                           per:origin
# 11              per:cities_of_residence    per:stateorprovinces_of_residence
# 12                         per:children                          per:parents
# 13          org:country_of_headquarters    per:stateorprovinces_of_residence
# 14           per:countries_of_residence                           per:origin
# 15              per:cities_of_residence                      per:employee_of
# 16                   per:cause_of_death                 per:schools_attended
# 17              per:cities_of_residence                 per:schools_attended
# 18              per:cities_of_residence                    per:city_of_death
# 19          org:country_of_headquarters  org:stateorprovince_of_headquarters
# 20                     per:other_family                         per:siblings
# 21                          org:parents  org:stateorprovince_of_headquarters
# 22                      per:employee_of                            per:title
# 23                          org:members                     org:subsidiaries
# 24                         per:children                           per:spouse
# 25          org:country_of_headquarters                            per:title
# 26                  org:alternate_names                              per:age
# 27           per:countries_of_residence                            per:title
# 28                     org:subsidiaries                     per:other_family
# 29                     org:subsidiaries                          per:parents
# 30             org:city_of_headquarters          org:country_of_headquarters
# 31          org:country_of_headquarters           per:countries_of_residence
# 32                     per:other_family                          per:parents
# 33                         per:children                     per:other_family
# 34          org:country_of_headquarters                          org:parents
# 35                  per:alternate_names                           per:spouse
# 36                       org:founded_by                          org:parents
# 37                         per:siblings                           per:spouse
# 38                          org:members                          per:parents
# 39              per:cities_of_residence                            per:title
# 40                     per:other_family                           per:spouse
# 41                     org:subsidiaries                           per:spouse
# 42                          org:founded                    per:date_of_death
# 43                           per:origin                            per:title
# 44                          org:members                           per:spouse
# 45          org:country_of_headquarters                      per:employee_of
# 46                  per:alternate_names              per:cities_of_residence
# 47          org:country_of_headquarters              per:cities_of_residence
# 48  org:political/religious_affiliation    per:stateorprovinces_of_residence
# 49                    per:city_of_death           per:countries_of_residence
# 50                          per:parents                           per:spouse
# 51                    per:city_of_death    per:stateorprovinces_of_residence
# 52              per:cities_of_residence                           per:origin
# 53             org:city_of_headquarters              per:cities_of_residence
# 54  org:political/religious_affiliation                      per:employee_of
# 55                       org:founded_by                         per:siblings
# 56  org:stateorprovince_of_headquarters           per:countries_of_residence
# 57                     org:subsidiaries                         per:children
# 58  org:stateorprovince_of_headquarters    per:stateorprovinces_of_residence
# 59                          org:members                         per:siblings
# 60                     org:subsidiaries            org:top_members/employees
# 61                          org:members                         per:children
# 62                 per:schools_attended    per:stateorprovinces_of_residence
# 63                       org:founded_by                     org:subsidiaries
# 64                          org:members            org:top_members/employees
# 65  org:political/religious_affiliation           per:countries_of_residence
# 66                       org:founded_by            org:top_members/employees
# 67                          org:parents                  per:alternate_names
# 68                          org:parents                           per:spouse
# 69                    per:city_of_death                      per:employee_of
# 70  org:stateorprovince_of_headquarters                      per:employee_of
# 71             org:city_of_headquarters    per:stateorprovinces_of_residence
# 72  org:political/religious_affiliation  org:stateorprovince_of_headquarters
# 73                          per:parents                         per:siblings
# 74             org:city_of_headquarters                            per:title
# 75                          org:parents    per:stateorprovinces_of_residence
# 76              per:cities_of_residence                           per:spouse
# 77                        org:member_of                    per:city_of_death
# 78                     org:subsidiaries                         per:siblings
# 79                          org:parents              per:cities_of_residence
# 80                      per:employee_of                 per:schools_attended
# 81            org:top_members/employees                          per:parents
# 82                   per:cause_of_death              per:cities_of_residence
# 83                       org:founded_by    per:stateorprovinces_of_residence
# 84             org:city_of_headquarters                       org:founded_by
# 85                          org:parents           per:countries_of_residence
# 86             org:city_of_headquarters                  per:alternate_names
# 87                       org:founded_by                  per:alternate_names
# 88                          org:parents                         per:siblings
# 89                   per:cause_of_death                           per:origin
# 90                       org:founded_by                     per:other_family
# 91  org:stateorprovince_of_headquarters              per:cities_of_residence
# 92                          org:parents                            per:title
# 93                  per:alternate_names                            per:title
# 94                  org:alternate_names                            per:title
# 95                          org:parents                      per:employee_of
# 96                           per:spouse                            per:title
# 97                    per:city_of_death                 per:schools_attended
# 98          org:country_of_headquarters                           per:origin
# 99             org:city_of_headquarters           per:countries_of_residence
#
#      jaccard
# 0   0.478088
# 1   0.460784
# 2   0.429150
# 3   0.378855
# 4   0.355450
# 5   0.351351
# 6   0.348000
# 7   0.343478
# 8   0.338235
# 9   0.335664
# 10  0.334928
# 11  0.334728
# 12  0.330769
# 13  0.330097
# 14  0.329268
# 15  0.319865
# 16  0.296943
# 17  0.281481
# 18  0.273764
# 19  0.273543
# 20  0.273504
# 21  0.268293
# 22  0.264706
# 23  0.264045
# 24  0.262857
# 25  0.262821
# 26  0.262346
# 27  0.259036
# 28  0.258741
# 29  0.251337
# 30  0.242678
# 31  0.242553
# 32  0.241935
# 33  0.239583
# 34  0.238579
# 35  0.234127
# 36  0.225806
# 37  0.224390
# 38  0.220859
# 39  0.219444
# 40  0.216867
# 41  0.215517
# 42  0.214876
# 43  0.211864
# 44  0.210784
# 45  0.209059
# 46  0.207143
# 47  0.203846
# 48  0.201923
# 49  0.198473
# 50  0.196262
# 51  0.193548
# 52  0.191781
# 53  0.187500
# 54  0.187500
# 55  0.185792
# 56  0.184615
# 57  0.184524
# 58  0.183673
# 59  0.182927
# 60  0.180124
# 61  0.179856
# 62  0.176245
# 63  0.169811
# 64  0.165541
# 65  0.165217
# 66  0.164557
# 67  0.164502
# 68  0.164444
# 69  0.164038
# 70  0.163462
# 71  0.160920
# 72  0.160714
# 73  0.160000
# 74  0.158904
# 75  0.157407
# 76  0.157343
# 77  0.156627
# 78  0.156566
# 79  0.156000
# 80  0.155015
# 81  0.153094
# 82  0.152985
# 83  0.151786
# 84  0.151639
# 85  0.150215
# 86  0.150000
# 87  0.149378
# 88  0.148352
# 89  0.145594
# 90  0.142857
# 91  0.142361
# 92  0.141975
# 93  0.141689
# 94  0.141487
# 95  0.141343
# 96  0.138122
# 97  0.137324
# 98  0.134831
# 99  0.134276
